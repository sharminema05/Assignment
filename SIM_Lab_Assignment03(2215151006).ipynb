# %% [markdown]
# <a href="https://colab.research.google.com/github/sharminema05/Assignment/blob/main/SIM_Lab_Assignment03(2215151006).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt

# %%
# Given data
data = np.array([5.2, 5.4, 5.1, 5.6, 5.3, 5.8])  # Provided dataset
hypothesized_mean = 5.5  # Null Hypothesis (H₀): The average value is 5.5

# Perform one-sample t-test
t_statistic, p_value = stats.ttest_1samp(data, hypothesized_mean)
ci = stats.t.interval(0.95, df=len(data)-1, loc=np.mean(data), scale=stats.sem(data))

# Interpretation
alpha = 0.05
reject_null = p_value < alpha

# %%
# Print results
print(f"Sample Mean: {np.mean(data):.2f}")
print(f"Hypothesized Population Mean: {hypothesized_mean:.2f}")
print(f"T-statistic: {t_statistic:.2f}")
print(f"Degrees of Freedom: {len(data) - 1}")
print(f"P-value: {p_value:.4f}")
print(f"Confidence Interval: [{ci[0]:.2f}, {ci[1]:.2f}]")
print("Conclusion:")
if reject_null:
    print(f"Reject the null hypothesis. The sample mean is significantly different from {hypothesized_mean:.2f}.")
else:
    print(f"Fail to reject the null hypothesis. The sample mean is not significantly different from {hypothesized_mean:.2f}.")
# Out:
# Sample Mean: 5.40
# Hypothesized Population Mean: 5.50
# T-statistic: -0.94
# Degrees of Freedom: 5
# P-value: 0.3907
# Confidence Interval: [5.13, 5.67]
# Conclusion:
# Fail to reject the null hypothesis. The sample mean is not significantly different from 5.50.

# %%
# Visualization
plt.figure(figsize=(8,5))
plt.bar(1, np.mean(data), color="skyblue", label='Sample Mean')
plt.errorbar(1, np.mean(data), yerr=np.std(data), fmt='k', linewidth=1.5)
plt.axhline(y=hypothesized_mean, color='r', linestyle='--', linewidth=1.5, label='Hypothesized Mean')
plt.title('Sample Mean vs Hypothesized Mean')
plt.xlim(0.5,1.5)
plt.xlabel('Sample')
plt.ylabel('Mean Value')
plt.legend()
plt.grid(True)
plt.show()
